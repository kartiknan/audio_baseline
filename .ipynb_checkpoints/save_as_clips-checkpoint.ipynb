# %% [markdown]
# # Raw Audio Files to Audio Clips for Feature Extraction
# Kartik Nanda, Feb 2020
#
# Read in the dowmloaded (raw) audio files and save them as clips to constant duration. These are
# then used for the purpose of feature extraction and further analysis

# %%
import numpy as np
import glob
import os
from pathlib import Path
import librosa
import librosa.display
import soundfile as sf
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# ## Define Constants

# %%
# Define some important constants - this needs to be moved to a separate included file
n_fft = 2048            # used for STFT: # samples used to generate fft
sample_rate = [44100, 8192, 1024]  # sample rates of the audio clips
cdur = 5                # clip duration in seconds
n_chroma = 12           # num of chroma bins to produce
n_mels = 128            # num of mel freq bands output
n_bands = 6             # num of contrast bands

# %% [markdown]
# ## Path Setup

# %% [markdown]
# We use the data in the datasets folder (Under-Water audio), and extract simple features from the audio files.
#
# The folder structure:
#
#     audio_anomaly_model/audio_baseline/ contains this script
#     audio_anomaly_model/datasets/ contains the dataset
#     audio_anomaly_model/features/ contains the features output

# %%
# Define paths
path_proj = Path.cwd().parent                        # The project directory
path_raw_audio = path_proj/'datasets'/'downloaded_converted_to_clips'   # The downloaded audio files
path_dataset = path_proj/'datasets'/'data_uw_sounds' # Dataset for Under-Water Audio 
path_features = path_proj/'features'                 # The output folder - where the features are saved (not used here)

# %%
# This is a list of all the directories which contain downloaded audio files
file_paths = list(path_raw_audio.glob('*'))

# %%
len(file_paths)
# Out:
# 36

# %%
# Read in the downloaded audio files, and split them into cdur sec segments and save as separate files
sr = sample_rate[0]
for p in file_paths:
    j=0
    files = list(p.glob('*.*'))
    print('*************** Folder (class): ', p.name, ' *******************')
    for f in files:
        if f.suffix != '.mp3':
            print('Audio File (downloaded): ', f.name)
            X, _sr = librosa.load(f, sr)
            print('Org. Sample rate: ', librosa.get_samplerate(f), ', Audio clips resampled at:', _sr)
            print('Number of audio samples: ', X.shape[0])
            num_clips = int(X.shape[0]/(sr*cdur))
            print('Writing ... number of clips: ', num_clips)
            for i in range(0, num_clips):
                outfile_name = p.name + '-' + str(i+j) + '.wav'
                sf.write(path_dataset/outfile_name, X[i*sr*cdur:(i+1)*sr*cdur], sr)
            j = j+i+1
        else: 
            print('File (', f.name, ') is mp3, skipped ...')
# Out:
# *************** Folder (class):  background  *******************
# Audio File (downloaded):  369485__mbari-mars_background.wav
# Org. Sample rate:  44100 , Audio clips resampled at: 44100
# Number of audio samples:  221959
# Writing ... number of clips:  1
# *************** Folder (class):  cod  *******************
# Audio File (downloaded):  cod.wav
# Org. Sample rate:  44100 , Audio clips resampled at: 44100
# Number of audio samples:  884736
# Writing ... number of clips:  4
# *************** Folder (class):  dolphin  *******************
# Audio File (downloaded):  265257__aguasonic__ag25feb015-trk05.wav
# Org. Sample rate:  48000 , Audio clips resampled at: 44100
# Number of audio samples:  1877837
# Writing ... number of clips:  8
# *************** Folder (class):  dolphin_bottlenose  *******************
# Audio File (downloaded):  324114__listeningtowhales__07-bottlenose-dolphins-with-humpback-whales.aiff
# Org. Sample rate:  44100 , Audio clips resampled at: 44100
# Number of audio samples:  3429804
# Writing ... number of clips:  15
# Audio File (downloaded):  bottlenose-dolphin.wav
# Org. Sample rate:  44100 , Audio clips resampled at: 44100
# Number of audio samples:  249984
# Writing ... number of clips:  1
# *************** Folder (class):  dolphin_rissos  *******************
# Audio File (downloaded):  rissos-dolphin.wav
# Org. Sample rate:  44100 , Audio clips resampled at: 44100
# Number of audio samples:  326016
# Writing ... number of clips:  1
# *************** Folder (class):  dolphin_short_beaked  *******************
# Audio File (downloaded):  short-beaked-common-dolphin.wav
# Org. Sample rate:  44100 , Audio clips resampled at: 44100
# Number of audio samples:  293343
# Writing ... number of clips:  1
# *************** Folder (class):  dolphin_spotted  *******************
# Audio File (downloaded):  385796__geraldfiebig__atlantic-spotted-dolphins-off-the-coast-of-la-gomera-canary-islands.wav
# Org. Sample rate:  48000 , Audio clips resampled at: 44100
# Number of audio samples:  6300566
# Writing ... number of clips:  28
# Audio File (downloaded):  atlantic-spotted-dolphin.wav
# Org. Sample rate:  48000 , Audio clips resampled at: 44100
# Number of audio samples:  307995
# Writing ... number of clips:  1
# *************** Folder (class):  dolphin_striped  *******************
# Audio File (downloaded):  striped-dolphin.wav
# Org. Sample rate:  48000 , Audio clips resampled at: 44100
# Number of audio samples:  1164240
# Writing ... number of clips:  5
# *************** Folder (class):  dolphin_white_beaked  *******************
# Audio File (downloaded):  white-beaked-dolphin.wav
# Org. Sample rate:  44100 , Audio clips resampled at: 44100
# Number of audio samples:  537984
# Writing ... number of clips:  2
# *************** Folder (class):  dolphin_white_sided  *******************
# Audio File (downloaded):  404148__mbari-mars__pacific-white-sided-dolphins.wav
# Org. Sample rate:  256000 , Audio clips resampled at: 44100
# Number of audio samples:  1461601
# Writing ... number of clips:  6
# Audio File (downloaded):  404313__mbari-mars__pacific-white-sided-dolphins.wav
# Org. Sample rate:  32000 , Audio clips resampled at: 44100
# Number of audio samples:  1461601
# Writing ... number of clips:  6
# Audio File (downloaded):  atlantic-white-sided-dolphin.wav
# Org. Sample rate:  44100 , Audio clips resampled at: 44100
# Number of audio samples:  1067904
# Writing ... number of clips:  4
# *************** Folder (class):  earthquake  *******************
# Audio File (downloaded):  369485__mbari-mars__earthquake-audible-only-with-appropriate-speakers.wav
# Org. Sample rate:  44100 , Audio clips resampled at: 44100
# Number of audio samples:  541693
# Writing ... number of clips:  2
# *************** Folder (class):  explosions  *******************
# Audio File (downloaded):  oil-and-gas-industries.wav
# Org. Sample rate:  8000 , Audio clips resampled at: 44100
# Number of audio samples:  1472626
# Writing ... number of clips:  6
# *************** Folder (class):  haddock  *******************
# Audio File (downloaded):  haddock.wav
# Org. Sample rate:  44100 , Audio clips resampled at: 44100
# Number of audio samples:  884736
# Writing ... number of clips:  4
# *************** Folder (class):  iceburg_noises  *******************
# Audio File (downloaded):  Iceburg_Calving.wav
# Org. Sample rate:  8000 , Audio clips resampled at: 44100
# Number of audio samples:  37335898
# Writing ... number of clips:  169
# Audio File (downloaded):  iceburg_grinding_to_halt.wav
# Org. Sample rate:  8000 , Audio clips resampled at: 44100
# Number of audio samples:  12770655
# Writing ... number of clips:  57
# Audio File (downloaded):  Iceburg_Tremor.wav
# Org. Sample rate:  999 , Audio clips resampled at: 44100
# Number of audio samples:  18371425
# Writing ... number of clips:  83
# Audio File (downloaded):  icequake.wav
# Org. Sample rate:  8000 , Audio clips resampled at: 44100
# Number of audio samples:  7297492
# Writing ... number of clips:  33
# *************** Folder (class):  orca  *******************
# Audio File (downloaded):  458854__mbari-mars__orcas-killer-whales.wav
# Org. Sample rate:  64000 , Audio clips resampled at: 44100
# Number of audio samples:  665037
# Writing ... number of clips:  3
# Audio File (downloaded):  orca-whale.wav
# Org. Sample rate:  32000 , Audio clips resampled at: 44100
# Number of audio samples:  2205177
# Writing ... number of clips:  10
# *************** Folder (class):  porpoise_harbor  *******************
# Audio File (downloaded):  harbor-porpoise.wav
# Org. Sample rate:  48000 , Audio clips resampled at: 44100
# Number of audio samples:  553544
# Writing ... number of clips:  2
# *************** Folder (class):  rain  *******************
# File ( 404317__mbari-mars__rain-heard-900-meters-below-the-sea-surface.mp3 ) is mp3, skipped ...
# *************** Folder (class):  seal_bearded  *******************
# Audio File (downloaded):  bearded-seal.wav
# Org. Sample rate:  11025 , Audio clips resampled at: 44100
# Number of audio samples:  2534400
# Writing ... number of clips:  11
# *************** Folder (class):  seal_crabeater  *******************
# Audio File (downloaded):  crabeater-seal.wav
# Org. Sample rate:  22050 , Audio clips resampled at: 44100
# Number of audio samples:  453204
# Writing ... number of clips:  2
# *************** Folder (class):  seal_gray  *******************
# Audio File (downloaded):  gray-seal.wav
# Org. Sample rate:  44100 , Audio clips resampled at: 44100
# Number of audio samples:  573505
# Writing ... number of clips:  2
# *************** Folder (class):  seal_harbor  *******************
# Audio File (downloaded):  harbor-seal.wav
# Org. Sample rate:  44100 , Audio clips resampled at: 44100
# Number of audio samples:  1168128
# Writing ... number of clips:  5
# *************** Folder (class):  seal_harp  *******************
# Audio File (downloaded):  harp-seal.wav
# Org. Sample rate:  44100 , Audio clips resampled at: 44100
# Number of audio samples:  1666944
# Writing ... number of clips:  7
# *************** Folder (class):  seal_leopard  *******************
# Audio File (downloaded):  leopard-seal.wav
# Org. Sample rate:  12000 , Audio clips resampled at: 44100
# Number of audio samples:  1648988
# Writing ... number of clips:  7
# *************** Folder (class):  seal_ross  *******************
# Audio File (downloaded):  ross-seal.wav
# Org. Sample rate:  22050 , Audio clips resampled at: 44100
# Number of audio samples:  2082816
# Writing ... number of clips:  9
# *************** Folder (class):  seal_weddell  *******************
# Audio File (downloaded):  weddell-seal.wav
# Org. Sample rate:  12000 , Audio clips resampled at: 44100
# Number of audio samples:  2624832
# Writing ... number of clips:  11
# *************** Folder (class):  vessel  *******************
# Audio File (downloaded):  noaa_ship.wav
# Org. Sample rate:  8000 , Audio clips resampled at: 44100
# Number of audio samples:  2371743
# Writing ... number of clips:  10
# Audio File (downloaded):  vessel.wav
# Org. Sample rate:  11025 , Audio clips resampled at: 44100
# Number of audio samples:  1366272
# Writing ... number of clips:  6
# *************** Folder (class):  whale_beaked  *******************
# File ( 404315__mbari-mars__beaked-whale-clicks.mp3 ) is mp3, skipped ...
# Audio File (downloaded):  beaked-whale.wav
# Org. Sample rate:  44100 , Audio clips resampled at: 44100
# Number of audio samples: